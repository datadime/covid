# %% [markdown]
# # Ѫ Start Here: EDA/Data Cleaning/Dataframe Making
#
# This notebook seeks to be a landing page for people looking to start working with the information made available in the UNCOVER dataset. It begins with an analysis of the basic data located in each of the folders examining the columns that exist.
#
# Additionally, I have made a utilities section that has some funcitons useful to working with dataframes.
#
# **Please up vote to let me know this is useful or comment on other ways to make this a valuable resource**

# %% [markdown]
# ## Data Meta-Analysis: Exploring the data, columns, and content
# ### General Stats

# %%
#Libraries Needed
import pandas as pd
import os
from glob import glob
from tqdm.notebook import tqdm

#Settings to display pandas
pd.set_option('display.max_columns', None)

#Some basic set up
base_path = "\Users\neesh\Documents\Data Sets\covid\uncover"
# Out:
#   File "<ipython-input-3-f3b295732d4e>", line 11
#     base_path = "\Users\neesh\Documents\Data Sets\covid\uncover"
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \UXXXXXXXX escape

# %%
#Traverse paths and pull out all .csv files
#Explaination at 
#https://perials.com/getting-csv-files-directory-subdirectories-using-python/
all_csv_files = []
for path, subdir, files in os.walk(base_path):
    for file in glob(os.path.join(path, "*.csv")):
        all_csv_files.append(file)
"There are a total of {} csv files in this dataset.".format(len(all_csv_files))
# Out:
# 'There are a total of 77 csv files in this dataset.'

# %%
#Try to make a pandas dataframe from each file
#The dataframes will be accessible by their file name using the uncover_df_dictionary
read_files = []
skipped_files = []
uncover_df_dictionary = {}
for file_path in tqdm(all_csv_files):
    df_name = file_path.split("/")[-1].strip(".csv")
    try:
        uncover_df_dictionary[df_name] = pd.read_csv(file_path, low_memory=False)
        read_files.append(file_path)
    except:
        read_files.append(file_path)
        pass
"Read a total of {} files into Pandas dataframes and skipped {}.".format(len(read_files), len(skipped_files))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=77.0), HTML(value='')))
# 'Read a total of 77 files into Pandas dataframes and skipped 0.'

# %% [markdown]
# ### Common Columns
# These could be used for merging dataframes. Columns are also called features. These can be used to build models or describe the data. This secton epxlores the columns that exist and how they relate to other dataframes. It also does some examination of how the categorical data maybe turned into numerical features.

# %%
#Iterate though dict and group similar
column_dict = {}
for name, df in uncover_df_dictionary.items():
    all_cols = list(df.columns)
    for col in all_cols:
        if col in column_dict.keys():
            column_dict[col].append(name)
        else:
            column_dict[col] = list([name])

#Drop any columns not found in other DataFrames
len_before_drop = len(column_dict)
to_pop = []
for col, df_list in column_dict.items():
    if len(df_list) < 2:
        to_pop.append(col)
        
#Run in seperate loop as can not change size in iterator
for col in to_pop:
    column_dict.pop(col)
    
print("A total of {} columns are unique to one dataframe.".format((len_before_drop-len(column_dict))))
print("A total of {} columns are shared by more than one dataframe.".format(len(column_dict)))

#Make DF with index of cols and a column of dfs with that feature
col_df = pd.DataFrame(pd.Series(column_dict)).reset_index()
col_df.columns = ["Feature", "DataFrames"]
col_df.head(1)
# Out:
# A total of 1292 columns are unique to one dataframe.
# A total of 395 columns are shared by more than one dataframe.
#        Feature                                         DataFrames
# 0  region_type  [restaurant-performance, restaurant-performanc...

# %% [markdown]
# Use pivot table to turn into binary matrix with columns as files and rows as available features. A 1 will represent it is present in the data and a 0 that it is not.

# %%
#Explode-Make a new row for each of the values found in the DataFrames lists
col_df_explode = col_df.explode("DataFrames")
#Add present columns to keep track of which are where
col_df_explode["present"] = 1
#Pivot to binary matrix
col_binary_matrix = col_df_explode.pivot_table(index='Feature',
                    columns='DataFrames',
                    values='present',
                    aggfunc='sum',
                    fill_value=0)
col_binary_matrix.head()
# Out:
# DataFrames  500-cities-census-tract-level-data-gis-friendly-format-2019-release  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  Hospitalization_all_lo  \
# Feature
# 1960                             0
# 1961                             0
# 1962                             0
# 1963                             0
# 1964                             0
#
# DataFrames  acaps-covid-19-government-measures-dataset  \
# Feature
# 1960                                                 0
# 1961                                                 0
# 1962                                                 0
# 1963                                                 0
# 1964                                                 0
#
# DataFrames  aircraft-landing-facilitie  ases-and-deaths-by-regions-in-belgium  \
# Feature
# 1960                                 0                                      0
# 1961                                 0                                      0
# 1962                                 0                                      0
# 1963                                 0                                      0
# 1964                                 0                                      0
#
# DataFrames  dcs-social-vulnerability-index-svi-2016-overall-svi-census-tract-level  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  dcs-social-vulnerability-index-svi-2016-overall-svi-county-level  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  definitive-healthcare-usa-hospital-bed  dphe-health-facilitie  \
# Feature
# 1960                                             0                      0
# 1961                                             0                      0
# 1962                                             0                      0
# 1963                                             0                      0
# 1964                                             0                      0
#
# DataFrames  environment-social-and-governance-data  global-population  \
# Feature
# 1960                                             1                  0
# 1961                                             1                  0
# 1962                                             1                  0
# 1963                                             1                  0
# 1964                                             1                  0
#
# DataFrames  global-school-closures-covid-19  \
# Feature
# 1960                                      0
# 1961                                      0
# 1962                                      0
# 1963                                      0
# 1964                                      0
#
# DataFrames  global-tobacco-surveillance-system-gtss-global-adult-tobacco-survey-gat  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  global-tobacco-surveillance-system-gtss-global-youth-tobacco-survey-gyt  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  health-population-country-summary  \
# Feature
# 1960                                        0
# 1961                                        0
# 1962                                        0
# 1963                                        0
# 1964                                        0
#
# DataFrames  health-population-health-nutrition-population  hospital  \
# Feature
# 1960                                                    0         0
# 1961                                                    0         0
# 1962                                                    0         0
# 1963                                                    0         0
# 1964                                                    0         0
#
# DataFrames  hospital-beds-per-1-000-people  \
# Feature
# 1960                                     1
# 1961                                     1
# 1962                                     1
# 1963                                     1
# 1964                                     1
#
# DataFrames  hospital-capacity-by-state-20-population-contracted  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  hospital-capacity-by-state-40-population-contracted  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  hospital-capacity-by-state-60-population-contracted  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  inform-covid-indicator  international-debt  \
# Feature
# 1960                             0                   0
# 1961                             0                   0
# 1962                             0                   0
# 1963                             0                   0
# 1964                             0                   0
#
# DataFrames  johns-hopkins-covid-19-daily-dashboard-case  \
# Feature
# 1960                                                  0
# 1961                                                  0
# 1962                                                  0
# 1963                                                  0
# 1964                                                  0
#
# DataFrames  johns-hopkins-covid-19-daily-dashboard-cases-by-country  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  johns-hopkins-covid-19-daily-dashboard-cases-by-state  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  johns-hopkins-covid-19-daily-dashboard-cases-over-time  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  limate-change  local-emergency-operations-centers-eo  \
# Feature
# 1960                    1                                      0
# 1961                    1                                      0
# 1962                    1                                      0
# 1963                    1                                      0
# 1964                    1                                      0
#
# DataFrames  moking-prevalence-total-ages-15  \
# Feature
# 1960                                      1
# 1961                                      1
# 1962                                      1
# 1963                                      1
# 1964                                      1
#
# DataFrames  nurses-and-midwives-per-1-000-people  nursing-home  \
# Feature
# 1960                                           1             0
# 1961                                           1             0
# 1962                                           1             0
# 1963                                           1             0
# 1964                                           1             0
#
# DataFrames  nutrition-physical-activity-and-obesity-behavioral-risk-factor-surveillance-system  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  ommunity-health-workers-per-1-000-people  \
# Feature
# 1960                                               1
# 1961                                               1
# 1962                                               1
# 1963                                               1
# 1964                                               1
#
# DataFrames  onfirmed-covid-19-cases-in-us-by-state-and-county  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  onfirmed-covid-19-deaths-in-us-by-state-and-county  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  oronavirus-world-airport-impact  ovid-19-county-level-data  \
# Feature
# 1960                                      0                          0
# 1961                                      0                          0
# 1962                                      0                          0
# 1963                                      0                          0
# 1964                                      0                          0
#
# DataFrames  ovid-19-genetic-phylogeny  \
# Feature
# 1960                                0
# 1961                                0
# 1962                                0
# 1963                                0
# 1964                                0
#
# DataFrames  ovid-19-italy-situation-monitoring-by-region  \
# Feature
# 1960                                                   0
# 1961                                                   0
# 1962                                                   0
# 1963                                                   0
# 1964                                                   0
#
# DataFrames  ovid-19-state-level-data  ovid-19-tracker-canada  \
# Feature
# 1960                               0                       0
# 1961                               0                       0
# 1962                               0                       0
# 1963                               0                       0
# 1964                               0                       0
#
# DataFrames  ovid-19-uk-historical-data  ovid-sources-for-countie  \
# Feature
# 1960                                 0                         0
# 1961                                 0                         0
# 1962                                 0                         0
# 1963                                 0                         0
# 1964                                 0                         0
#
# DataFrames  ovid-sources-for-us-state  \
# Feature
# 1960                                0
# 1961                                0
# 1962                                0
# 1963                                0
# 1964                                0
#
# DataFrames  ovid-statistics-by-us-states-daily-update  \
# Feature
# 1960                                                0
# 1961                                                0
# 1962                                                0
# 1963                                                0
# 1964                                                0
#
# DataFrames  ovid-statistics-by-us-states-total  \
# Feature
# 1960                                         0
# 1961                                         0
# 1962                                         0
# 1963                                         0
# 1964                                         0
#
# DataFrames  ovid-statistics-for-all-us-daily-update  \
# Feature
# 1960                                              0
# 1961                                              0
# 1962                                              0
# 1963                                              0
# 1964                                              0
#
# DataFrames  ovid-statistics-for-all-us-total  \
# Feature
# 1960                                       0
# 1961                                       0
# 1962                                       0
# 1963                                       0
# 1964                                       0
#
# DataFrames  ovid19-epidemic-french-national-data  \
# Feature
# 1960                                           0
# 1961                                           0
# 1962                                           0
# 1963                                           0
# 1964                                           0
#
# DataFrames  pecialist-surgical-workforce-per-100-000-population  \
# Feature
# 1960                                                        1
# 1961                                                        1
# 1962                                                        1
# 1963                                                        1
# 1964                                                        1
#
# DataFrames  people-with-basic-handwashing-facilities-including-soap-and-water-of-population  \
# Feature
# 1960                                                        1
# 1961                                                        1
# 1962                                                        1
# 1963                                                        1
# 1964                                                        1
#
# DataFrames  per-million-people-tests-conducted-vs-total-confirmed-cases-of-covid-19  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  physicians-per-1-000-people  public-covid-19-cases-canada  \
# Feature
# 1960                                  1                             0
# 1961                                  1                             0
# 1962                                  1                             0
# 1963                                  1                             0
# 1964                                  1                             0
#
# DataFrames  public-health-department  restaurant-performance  \
# Feature
# 1960                               0                       0
# 1961                               0                       0
# 1962                               0                       0
# 1963                               0                       0
# 1964                               0                       0
#
# DataFrames  restaurant-performance-city  restaurant-performance-country  \
# Feature
# 1960                                  0                               0
# 1961                                  0                               0
# 1962                                  0                               0
# 1963                                  0                               0
# 1964                                  0                               0
#
# DataFrames  restaurant-performance-state  \
# Feature
# 1960                                   0
# 1961                                   0
# 1962                                   0
# 1963                                   0
# 1964                                   0
#
# DataFrames  rowd-sourced-covid-19-testing-location  \
# Feature
# 1960                                             0
# 1961                                             0
# 1962                                             0
# 1963                                             0
# 1964                                             0
#
# DataFrames  tests-conducted-vs-total-confirmed-cases-of-covid-19  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  total-covid-19-tests-performed-by-country  \
# Feature
# 1960                                                0
# 1961                                                0
# 1962                                                0
# 1963                                                0
# 1964                                                0
#
# DataFrames  total-covid-19-tests-performed-per-million-people  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  tuberculosis-case-notification  \
# Feature
# 1960                                     0
# 1961                                     0
# 1962                                     0
# 1963                                     0
# 1964                                     0
#
# DataFrames  u-s-chronic-disease-indicators-cdi  urgent-care-facilitie  \
# Feature
# 1960                                         0                      0
# 1961                                         0                      0
# 1962                                         0                      0
# 1963                                         0                      0
# 1964                                         0                      0
#
# DataFrames  urrent-data-on-the-geographic-distribution-of-covid-19-cases-worldwide  \
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0
#
# DataFrames  us-county-health-rankings-2020  who-situation-reports-covid-19  \
# Feature
# 1960                                     0                               0
# 1961                                     0                               0
# 1962                                     0                               0
# 1963                                     0                               0
# 1964                                     0                               0
#
# DataFrames  world-development-indicators-country-summary  \
# Feature
# 1960                                                   0
# 1961                                                   0
# 1962                                                   0
# 1963                                                   0
# 1964                                                   0
#
# DataFrames  world-travel-restriction  \
# Feature
# 1960                               0
# 1961                               0
# 1962                               0
# 1963                               0
# 1964                               0
#
# DataFrames  worldometer-confirmed-cases-and-deaths-by-country-territory-or-conveyance
# Feature
# 1960                                                        0
# 1961                                                        0
# 1962                                                        0
# 1963                                                        0
# 1964                                                        0

# %% [markdown]
# Columns most commonly found

# %%
col_binary_matrix.sum(axis=1).sort_values(ascending=False).head(10)
# Out:
# Feature
# state             22
# date              21
# country           17
# fips              15
# country_code      14
# geometry          14
# county            12
# objectid          11
# country_name      11
# indicator_code    11
# dtype: int64

# %% [markdown]
# DataFrames that share the most features

# %%
#Get all possible file combinaitons to compare
from itertools import permutations
all_pairs = permutations(col_binary_matrix.columns,2)
pairs_df_list = []
for df1, df2 in all_pairs:
    boolean_check = (col_binary_matrix[df1]==1) & (col_binary_matrix[df2]==1)
    shared_feats = list(col_binary_matrix.index[boolean_check])
    num_shared_feats = len(shared_feats)
    features_dict = {"df1":df1, "df2": df2,"sim_col_count": num_shared_feats,"sim_col_list": shared_feats}
    if num_shared_feats > 1:
        pairs_df_list.append(features_dict)
shared_cols_dfs = pd.DataFrame(pairs_df_list).sort_values("sim_col_count", ascending=False)
shared_cols_dfs.head(10)
# Out:
#                                                    df1  \
# 44   dcs-social-vulnerability-index-svi-2016-overal...
# 27   dcs-social-vulnerability-index-svi-2016-overal...
# 149                     hospital-beds-per-1-000-people
# 241               nurses-and-midwives-per-1-000-people
# 243               nurses-and-midwives-per-1-000-people
# 245               nurses-and-midwives-per-1-000-people
# 246               nurses-and-midwives-per-1-000-people
# 247               nurses-and-midwives-per-1-000-people
# 248               nurses-and-midwives-per-1-000-people
# 244               nurses-and-midwives-per-1-000-people
#
#                                                    df2  sim_col_count  \
# 44   dcs-social-vulnerability-index-svi-2016-overal...            127
# 27   dcs-social-vulnerability-index-svi-2016-overal...            127
# 149                    moking-prevalence-total-ages-15             64
# 241                     hospital-beds-per-1-000-people             64
# 243                                      limate-change             64
# 245           ommunity-health-workers-per-1-000-people             64
# 246  pecialist-surgical-workforce-per-100-000-popul...             64
# 247  people-with-basic-handwashing-facilities-inclu...             64
# 248                        physicians-per-1-000-people             64
# 244                    moking-prevalence-total-ages-15             64
#
#                                           sim_col_list
# 44   [area_sqmi, county, e_age17, e_age65, e_crowd,...
# 27   [area_sqmi, county, e_age17, e_age65, e_crowd,...
# 149  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# 241  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# 243  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# 245  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# 246  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# 247  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# 248  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# 244  [1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
