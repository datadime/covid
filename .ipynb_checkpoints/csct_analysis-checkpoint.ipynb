# %%
pwd
# Out:
# 'C:\\Users\\neesh\\Documents\\GitHub\\covid'

# %%
import pandas as pd

# %%
#Some basic set up
base_path = "C:\\Users\\neesh\\Documents\\Data Sets\\covid\\uncover"

# %%
csct = pd.read_csv(base_path + '\\coders_against_covid\\crowd-sourced-covid-19-testing-locations.csv')

# %%
csct = pd.DataFrame(csct)

# %%
csct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4159 entries, 0 to 4158
# Data columns (total 27 columns):
# location_id                                             4159 non-null object
# is_verified                                             4159 non-null object
# is_hidden                                               4159 non-null object
# is_location_screening_patients                          4120 non-null object
# is_location_collecting_specimens                        4152 non-null object
# location_name                                           4159 non-null object
# location_address_street                                 4159 non-null object
# location_address_locality                               4159 non-null object
# location_address_region                                 4159 non-null object
# location_address_postal_code                            708 non-null float64
# lat                                                     4159 non-null float64
# ...

# %%
csct = csct.drop(columns=['additional_information_for_patients','is_ready_for_prod','location_address_district','location_specific_testing_criteria','location_contact_url_appointments','location_contact_phone_appointments','location_contact_phone_main','location_contact_url_main'])

# %%
csct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4159 entries, 0 to 4158
# Data columns (total 19 columns):
# location_id                                             4159 non-null object
# is_verified                                             4159 non-null object
# is_hidden                                               4159 non-null object
# is_location_screening_patients                          4120 non-null object
# is_location_collecting_specimens                        4152 non-null object
# location_name                                           4159 non-null object
# location_address_street                                 4159 non-null object
# location_address_locality                               4159 non-null object
# location_address_region                                 4159 non-null object
# location_address_postal_code                            708 non-null float64
# lat                                                     4159 non-null float64
# ...

# %%
csct.head()
# Out:
#                             location_id is_verified is_hidden  \
# 0  a3b3214a-e128-4c68-ac18-a467482f1ab8           t         f
# 1  823ece97-d901-4dd6-9a4e-b5a86d61230e           t         f
# 2  f15df801-b396-45d7-b689-c0cc7fca3e0b           t         f
# 3  ff18e912-fe0f-4823-a4cb-698e3f92a345           t         f
# 4  372769c0-2497-4353-8a4f-035e9e575852           t         f
#
#   is_location_screening_patients is_location_collecting_specimens  \
# 0                              t                                t
# 1                              f                                f
# 2                              t                                t
# 3                              t                                t
# 4                              t                                t
#
#                                   location_name     location_address_street  \
# 0              Providence Alaska Medical Center       3200 Providence Drive
# ...

# %%
csct_summary =  pd.DataFram(data = csct.(['location_address_region'].count()))

# %%
csct_summary.head()
# Out:
#                          location_id  is_verified  is_hidden  \
# location_address_region
# AK                                41           41         41
# AL                                74           74         74
# AZ                                 3            3          3
# Arizona                           34           34         34
# Arkansas                          46           46         46
#
#                          is_location_screening_patients  \
# location_address_region
# AK                                                   41
# AL                                                   74
# AZ                                                    2
# Arizona                                              34
# Arkansas                                             46
#
#                          is_location_collecting_specimens  location_name  \
# location_address_region
# AK                                                     41             41
# ...

# %%
d = {'state':[csct['location_address_region'].()]}

# %%
d1 = csct.groupby('location_address_region')

# %%
d1

# %%
csct_summary =  pd.DataFrame(d)

# %%
csct_summary
# Out:
#                                                state  \
# 0  MA         288
# Vermont    233
# Florida    217
# T...
#
#                                        #of_locations
# 0  MA         288
# Vermont    233
# Florida    217
# T...
